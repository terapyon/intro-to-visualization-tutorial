# %% [markdown]
# # 3-1-可視化ツール

# %% [markdown]
# ## 3-1-1-可視化ツールの分類
#
# > https://github.com/rougier/python-visualization-landscape
#
# ![](https://github.com/rougier/python-visualization-landscape/blob/master/landscape-colors.png?raw=true)
#
# 大まかには下記の2つに分類される
#
# * Matplotlibをベースとした静的な画像に描画するツール
# * JavaScriptをベースとしたHTMLにレンダリングするツール
#
# ## 3-1-2-代表的な可視化ツール
#
# ### Matplotlib
#
# * Pythonで最も広く使われている可視化ツール
# * pandasやseabornなどから間接的に使われることも
# * MATLABライクな記述方法とPythonライクな記述方法がある
#
# ### seaborn
#
# * MatplotlibやScipyなどを利用して統計的なグラフを作成できる
# * 特定の目的に沿ったグラフを短いコードで記述できる
#
# ### Bokeh
#
# * JavaScriptでレンダリングされたグラフをPythonで記述できる
# * 対話的で動きがあるグラフを作成できる
# * Pythonユーザを意識した設計になっている
#
# ### Plotly
#
# * JavaScriptでレンダリングされたグラフをPythonで記述できる
# * 対話的で動きがあるグラフを作成できる
# * 多言語に対応している（JavaScript, R, Juliaなど）

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

np.random.seed(1)
data = pd.DataFrame(np.random.randn(100, 2), columns=list("AB"))

# %% [markdown]
# ## Matplotlibの例

# %%
fig = plt.figure(figsize=(6, 6))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

ax1.hist(data["A"])
ax2.scatter(data["B"], data["A"])
ax3.scatter(data["A"], data["B"])
ax4.hist(data["B"])
# Out:
# (array([ 4.,  3.,  6., 16., 14., 20., 18., 13.,  3.,  3.]),
#  array([-2.43483776, -1.97265602, -1.51047428, -1.04829254, -0.5861108 ,
#         -0.12392906,  0.33825268,  0.80043442,  1.26261616,  1.72479791,
#          2.18697965]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## seabornの例
#
# 簡素な記述でMatplotlibのグラフを描画できる

# %%
sns.pairplot(data)
