# %% [markdown]
# # 1-5-数値の演算子
#
# 演算子を紹介
#
# - 足し算
# - 引き算
# - 掛け算
# - 割り算
# - 余り
# - 累乗
# - dot積

# %%
1 + 2
# Out:
# 3

# %%
1.0 + 2
# Out:
# 3.0

# %%
1 - 2
# Out:
# -1

# %%
1 - 2.0
# Out:
# -1.0

# %%
1 * 2
# Out:
# 2

# %%
1.0 * 2
# Out:
# 2.0

# %%
1 / 2
# Out:
# 0.5

# %%
2 / 1
# Out:
# 2.0

# %%
2 // 1
# Out:
# 2

# %%
3 % 2
# Out:
# 1

# %%
3 ** 2
# Out:
# 9

# %%
import numpy as np
np.array([[2, 3]]) @ np.array([[3], [2]])
# Out:
# array([[12]])
