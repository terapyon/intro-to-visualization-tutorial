# %% [markdown]
# # 数値の扱い
#
# - 整数
# - 小数
# - 複素数
# - 二進数

# %% [markdown]
# # 整数

# %%
1
# Out:
# 1

# %%
300
# Out:
# 300

# %% [markdown]
# # 小数

# %%
1.0
# Out:
# 1.0

# %%
1.
# Out:
# 1.0

# %%
.9
# Out:
# 0.9

# %%
1e10
# Out:
# 10000000000.0

# %%
1e-1
# Out:
# 0.1

# %% [markdown]
# # 複素数

# %%
1 + 1j
# Out:
# (1+1j)

# %%
3j
# Out:
# 3j

# %%
abs(1 + 1j)
# Out:
# 1.4142135623730951

# %%
abs(3j)
# Out:
# 3.0

# %%
import cmath
cmath.phase(3 + 4j)
# Out:
# 0.9272952180016122

# %%
import math
math.degrees(cmath.phase(3 + 4j))
# Out:
# 53.13010235415598

# %%
c = complex(1, 1.73)
math.degrees(cmath.phase(c))
# Out:
# 59.97059823848534

# %%
c = complex(1, math.sqrt(3))
math.degrees(cmath.phase(c))
# Out:
# 59.99999999999999

# %% [markdown]
# # 二進数

# %%
0b10
# Out:
# 2

# %%
bin(4)
# Out:
# '0b100'
